# %% [markdown]
# # Lecture 2
# # Multiple scales
#
# - Boundary layer examples show that there are different length scales
#
# $$\ddot{y} + \sigma \dot{y} + y = 0$$
# $$\ddot{y} + \sigma \dot{y} + y = 0$$
# Page 15 Notes
#
# $$ \frac {d}{dt} =  \frac{d t_1}{dt}   \frac{\delta }{\delta t_1} + \frac{dt_2}{dt} \frac{\delta }{\delta t_2} \frac{\delta }{\delta t_1} + \epsilon \frac{\delta }{\delta t_2}$$

# %% [markdown]
# <img src="data:image/png;base64,..." alt="image.png">

# %% [markdown]
# <img src="data:image/png;base64,..." alt="image.png">

# %% [markdown]
# Dont want the secular terms ( sin and cosine) -> this makes things tend to infinty, thus set terms to 0 to give the terms
# $$2\frac{db_0}{dt_2}+b_0 = 0 $$
# $$2\frac{da_0}{dt_2}+a_0 = 0 $$
#
# rearanging, plugging in bcs $a_0(0) = 1 $ and $b_0(0)=0$  gives $$ b_0 = 0$$ $$a_0 = e^{-t_2/2}$$
# Only solving for $y_0$ (for more terms, plug epsilon 1 and bcs )

# %% [markdown]
# ### Key points of Multiple scales
#
# 1. care needed in choosing different scales
# 2. removal of secular terms is a key feature
# 3. sometimes more than two scales are required

# %% [markdown]
# <img src="data:image/png;base64,..." alt="image.png">

# %% [markdown]
# $$\epsilon \ddot{y{ + 2\dot{y} + 2y = 0$$
# $$ X_1 = x$$
# $$ X_2 = \frac{x}{\epsilon}$$
# $$\frac{d}{dx} == \frac{dx_1}{dx} \frac{\delta }{\delta x_1}$$
# $$(\epsilon \frac{\delta}{\delta x_1} + \frac{\delta}{\delta x} )(\epsilon \frac{dy}{dx_1}+ \frac{\delta y}{\delta x_2}) + 2(\epsilon \frac{\delta y}{\delta x_1} + \frac{\delta y}{\delta x_2} + 2 \epsilon y) = 0$$
#
#
#
# Multiply through by epsilon

# %% [markdown]
# <img src="data:image/png;base64,..." alt="image.png">
